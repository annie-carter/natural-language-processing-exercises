# %% [markdown]
# # <Span style = 'color: #008B8B'>Data Preparation

# %%
#panda 
import pandas as pd
import os
import acquire as a
from time import strftime


# unicode, regex, json for text digestion
import unicodedata
import re
import json

# nltk: natural language toolkit -> tokenization, stopwords
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords




import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <Span style = 'color: #008B8B'>Exercises
# The end result of this exercise should be a file named prepare.py that defines the requested functions.
#
# In this exercise we will be defining some functions to prepare textual data. These functions should apply equally well to both the codeup blog articles and the news articles that were previously acquired.

# %% [markdown]
# #### 1. Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# Lowercase everything
# Normalize unicode characters
# Replace anything that is not a letter, number, whitespace or a single quote.

# %%
## can turn on and off ascii and utf 

# we will define a basic_clean function for a single document (one string)
def basic_clean(string):
    '''
    This function takes in a string and
    returns the string normalized.
    '''
    # we will normalize our data into standard NFKD unicode, feed it into an ascii encoding
    # decode it back into UTF-8
    string = unicodedata.normalize('NFKD', string)\
             .encode('ascii', 'ignore')\
             .decode('utf-8', 'ignore')
    # utilize our regex substitution to remove our undesirable characters, then lowercase
    string = re.sub(r"[^\w0-9'\s]", '', string).lower()
    return string

# %% [markdown]
# #### 2.Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string):
    '''
    This function takes in a string and
    returns a tokenized string.
    '''
    # make our tokenizer, taken from nltk's ToktokTokenizer
    tokenizer = nltk.tokenize.ToktokTokenizer()
    # apply our tokenizer's tokenization to the string being input, ensure it returns a string
    string = tokenizer.tokenize(string, return_str = True)
    
    return string

# %% [markdown]
# #### 3. Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    '''
    This function takes in a string and
    returns a string with words stemmed.
    '''
    # create our stemming object
    ps = nltk.porter.PorterStemmer()
    # use a list comprehension => stem each word for each word inside of the entire document,
    # split by the default, which are single spaces
    stems = [ps.stem(word) for word in string.split()]
    # glue it back together with spaces, as it was before
    string = ' '.join(stems)
    
    return string

# %% [markdown]
# #### 4. Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(string):
    '''
    This function takes in string for and
    returns a string with words lemmatized.
    '''
    # create our lemmatizer object
    wnl = nltk.stem.WordNetLemmatizer()
    # use a list comprehension to lemmatize each word
    # string.split() => output a list of every token inside of the document
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    # glue the lemmas back together by the strings we split on
    string = ' '.join(lemmas)
    #return the altered document
    return string

# %% [markdown]
# #### 4. Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.

# %%
def remove_stopwords(string, extra_words = [], exclude_words = []):
    '''
    This function takes in a string, optional extra_words and exclude_words parameters
    with default empty lists and returns a string.
    '''
    # assign our stopwords from nltk into stopword_list
    stopword_list = stopwords.words('english')
    # utilizing set casting, i will remove any excluded stopwords
    stopword_set = set(stopword_list) - set(exclude_words)
    # add in any extra words to my stopwords set using a union
    stopword_set = stopword_set.union(set(extra_words))
    # split our document by spaces
    words = string.split()
    # every word in our document, as long as that word is not in our stopwords
    filtered_words = [word for word in words if word not in stopword_set]
    # glue it back together with spaces, as it was so it shall be
    string_without_stopwords = ' '.join(filtered_words)
    # return the document back
    return string_without_stopwords

# %% [markdown]
# #### 5. This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %% [markdown]
# #### 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
news_df = a.get_news_articles_data()
news_df
# Out:
#                                                 title  \
# 0   Antfin transfers 10.3% stake to Paytm chief Vi...
# 1   Nepal asks India for rice, sugar to avert poss...
# 2   GQG Partners buys 8.1% stake in Adani Power fo...
# 3   USDA cuts rice trade forecast for 2023, 2024 p...
# 4   Hyundai to buy General Motors' Talegaon plant ...
# 5   Nifty50 firms chiefs' average remuneration dro...
# 6   H&M probes labour abuses at Myanmar garment fa...
# 7   Irish bank glitch lets people with no money wi...
# 8   Union Cabinet approves ₹32,500 crore for seven...
# 9            Netherlands slips into recession
# 10  India's Gukesh D, Vidit Gujrathi crash out of ...
# 11  After scoring 369 runs in 2 matches, Shaw rule...
# 12  I do not make the pitch, I do not roll the pit...
# 13  Kishan flaunts his new MS Dhoni-like look with...
# 14  Imran is our greatest player: Ex-Pak captain M...
# 15  Was smashed for sixes, had to learn a lot: Ash...
# 16  Kohli demanded excellence, current team lacks ...
# 17  Dhawan doesn't get credit, he was missed in 20...
# 18  I guess he will get his British passport soon,...
# 19  Ravichandran Ashwin clarifies his 'Now everybo...
# 20  I've been locked out of X for 17 days after re...
# 21  Scientists reconstruct Pink Floyd song from re...
# 22  Russia's Luna-25 spacecraft enters lunar orbit...
# 23  Aditya-L1 to study the Sun's atmosphere, space...
# 24  Cabinet extends Digital India program with ₹14...
# 25  TweetDeck now called XPro, goes behind paywall...
# 26  Heartening: MoS Science on Chandrayaan-3 finis...
# 27  Why is Apple paying $500 million to select iPh...
# 28  Tech has progressed faster in India compared t...
# 29  17 & 18-year-olds accused of hacking Nvidia, b...
# 30  Aditya & Karan couldn't make better films than...
# 31  I am seriously considering making Mahabharat: ...
# 32  Govt refutes report of Gadar 2 'VIP screening'...
# 33  Salman Khan once called me a fat cow, said 'ev...
# 34  Was offered Sidharth Shukla's season of Bigg B...
# 35  Ranbir Kapoor buys Range Rover car worth ₹4 cr...
# 36  SRK reacts to Gauri's post on Suhana, says she...
# 37  Can be my authentic self with him: Alia on Ran...
# 38  Alia talks about 'toxicity' amid criticism aga...
# 39  Was 18, it was my homecoming as Miss Universe:...
#
#                                               content       category
# 0   Antfin (Netherlands) Holding BV has transferre...       business
# 1   Nepal government has requested India to facili...       business
# 2   Investment firm GQG Partners bought an 8.1% st...       business
# 3   US Department of Agriculture (USDA) lowered th...       business
# 4   Hyundai Motor India signed an asset purchase a...       business
# 5   Combined remuneration for the heads of the Nif...       business
# 6   H&M is investigating 20 alleged instances of l...       business
# 7   A glitch in Bank of Ireland's app allowed cust...       business
# 8   Union Cabinet approved a ₹32,500-crore budget ...       business
# 9   The Dutch economy has entered a recession as i...       business
# 10  India's Gukesh D and Vidit Gujrathi have crash...         sports
# 11  Northamptonshire's Indian batter Prithvi Shaw ...         sports
# 12  Talking about rank turners in India, all-round...         sports
# 13  Team India wicketkeeper-batter Ishan Kishan to...         sports
# 14  Talking about Pakistan's 1992 World Cup-winnin...         sports
# 15  Talking about his first tour of Australia in 2...         sports
# 16  Ex-India cricketer Balwinder Singh Sandhu, who...         sports
# 17  Ex-Team India head coach Ravi Shastri said bat...         sports
# 18  Talking about Cheteshwar Pujara's county crick...         sports
# 19  Ravichandran Ashwin clarified his remark where...         sports
# 20  Scott Galloway, a Professor of Marketing at NY...     technology
# 21  Researchers from the University of California,...     technology
# 22  Russia's lunar spacecraft entered the Moon's o...     technology
# 23  The Indian Space Research Organisation (ISRO) ...     technology
# 24  The Cabinet has extended Digital India program...     technology
# 25  XPro, earlier called TweetDeck, has been put b...     technology
# 26  After ISRO said it had successfully carried ou...     technology
# 27  Apple will start paying $500 million ($65 each...     technology
# 28  Intel's Executive Vice President and General M...     technology
# 29  A 17 and an 18-year-old are accused of being "...     technology
# 30  Actress Farida Jalal said she still feels that...  entertainment
# 31  Filmmaker Vivek Agnihotri said he is "seriousl...  entertainment
# 32  Government has refuted report of an "Exclusive...  entertainment
# 33  Speaking with Siddharth Kannan, Rohit Roy reca...  entertainment
# 34  Rapper Emiway Bantai shared he was offered 'Bi...  entertainment
# 35  Actor Ranbir Kapoor has bought a new Range Rov...  entertainment
# 36  Shah Rukh Khan, reacting to Gauri Khan's post ...  entertainment
# 37  Actress Alia Bhatt, during an Ask Me Anything ...  entertainment
# 38  Alia Bhatt talked about "toxicity and criticis...  entertainment
# 39  Sushmita Sen, reacting to an old picture, reca...  entertainment

# %% [markdown]
# #### 7. Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
codeup_df = a.blog_soup()
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              content
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...

# %% [markdown]
# #### 8. For each dataframe, produce the following columns:
#
# title to hold the title
# original to hold the original article/post content
# clean to hold the normalized and tokenized original with the stopwords removed.
# stemmed to hold the stemmed version of the cleaned data.
# lemmatized to hold the lemmatized version of the cleaned data.

# %%
news_df.rename(columns={'content': 'original'}, inplace=True)
codeup_df.rename(columns={'content': 'original'}, inplace=True)

# %%
news_df
# Out:
#                                                 title  \
# 0   Antfin transfers 10.3% stake to Paytm chief Vi...
# 1   Nepal asks India for rice, sugar to avert poss...
# 2   GQG Partners buys 8.1% stake in Adani Power fo...
# 3   USDA cuts rice trade forecast for 2023, 2024 p...
# 4   Hyundai to buy General Motors' Talegaon plant ...
# 5   Nifty50 firms chiefs' average remuneration dro...
# 6   H&M probes labour abuses at Myanmar garment fa...
# 7   Irish bank glitch lets people with no money wi...
# 8   Union Cabinet approves ₹32,500 crore for seven...
# 9            Netherlands slips into recession
# 10  India's Gukesh D, Vidit Gujrathi crash out of ...
# 11  After scoring 369 runs in 2 matches, Shaw rule...
# 12  I do not make the pitch, I do not roll the pit...
# 13  Kishan flaunts his new MS Dhoni-like look with...
# 14  Imran is our greatest player: Ex-Pak captain M...
# 15  Was smashed for sixes, had to learn a lot: Ash...
# 16  Kohli demanded excellence, current team lacks ...
# 17  Dhawan doesn't get credit, he was missed in 20...
# 18  I guess he will get his British passport soon,...
# 19  Ravichandran Ashwin clarifies his 'Now everybo...
# 20  I've been locked out of X for 17 days after re...
# 21  Scientists reconstruct Pink Floyd song from re...
# 22  Russia's Luna-25 spacecraft enters lunar orbit...
# 23  Aditya-L1 to study the Sun's atmosphere, space...
# 24  Cabinet extends Digital India program with ₹14...
# 25  TweetDeck now called XPro, goes behind paywall...
# 26  Heartening: MoS Science on Chandrayaan-3 finis...
# 27  Why is Apple paying $500 million to select iPh...
# 28  Tech has progressed faster in India compared t...
# 29  17 & 18-year-olds accused of hacking Nvidia, b...
# 30  Aditya & Karan couldn't make better films than...
# 31  I am seriously considering making Mahabharat: ...
# 32  Govt refutes report of Gadar 2 'VIP screening'...
# 33  Salman Khan once called me a fat cow, said 'ev...
# 34  Was offered Sidharth Shukla's season of Bigg B...
# 35  Ranbir Kapoor buys Range Rover car worth ₹4 cr...
# 36  SRK reacts to Gauri's post on Suhana, says she...
# 37  Can be my authentic self with him: Alia on Ran...
# 38  Alia talks about 'toxicity' amid criticism aga...
# 39  Was 18, it was my homecoming as Miss Universe:...
#
#                                              original       category
# 0   Antfin (Netherlands) Holding BV has transferre...       business
# 1   Nepal government has requested India to facili...       business
# 2   Investment firm GQG Partners bought an 8.1% st...       business
# 3   US Department of Agriculture (USDA) lowered th...       business
# 4   Hyundai Motor India signed an asset purchase a...       business
# 5   Combined remuneration for the heads of the Nif...       business
# 6   H&M is investigating 20 alleged instances of l...       business
# 7   A glitch in Bank of Ireland's app allowed cust...       business
# 8   Union Cabinet approved a ₹32,500-crore budget ...       business
# 9   The Dutch economy has entered a recession as i...       business
# 10  India's Gukesh D and Vidit Gujrathi have crash...         sports
# 11  Northamptonshire's Indian batter Prithvi Shaw ...         sports
# 12  Talking about rank turners in India, all-round...         sports
# 13  Team India wicketkeeper-batter Ishan Kishan to...         sports
# 14  Talking about Pakistan's 1992 World Cup-winnin...         sports
# 15  Talking about his first tour of Australia in 2...         sports
# 16  Ex-India cricketer Balwinder Singh Sandhu, who...         sports
# 17  Ex-Team India head coach Ravi Shastri said bat...         sports
# 18  Talking about Cheteshwar Pujara's county crick...         sports
# 19  Ravichandran Ashwin clarified his remark where...         sports
# 20  Scott Galloway, a Professor of Marketing at NY...     technology
# 21  Researchers from the University of California,...     technology
# 22  Russia's lunar spacecraft entered the Moon's o...     technology
# 23  The Indian Space Research Organisation (ISRO) ...     technology
# 24  The Cabinet has extended Digital India program...     technology
# 25  XPro, earlier called TweetDeck, has been put b...     technology
# 26  After ISRO said it had successfully carried ou...     technology
# 27  Apple will start paying $500 million ($65 each...     technology
# 28  Intel's Executive Vice President and General M...     technology
# 29  A 17 and an 18-year-old are accused of being "...     technology
# 30  Actress Farida Jalal said she still feels that...  entertainment
# 31  Filmmaker Vivek Agnihotri said he is "seriousl...  entertainment
# 32  Government has refuted report of an "Exclusive...  entertainment
# 33  Speaking with Siddharth Kannan, Rohit Roy reca...  entertainment
# 34  Rapper Emiway Bantai shared he was offered 'Bi...  entertainment
# 35  Actor Ranbir Kapoor has bought a new Range Rov...  entertainment
# 36  Shah Rukh Khan, reacting to Gauri Khan's post ...  entertainment
# 37  Actress Alia Bhatt, during an Ask Me Anything ...  entertainment
# 38  Alia Bhatt talked about "toxicity and criticis...  entertainment
# 39  Sushmita Sen, reacting to an old picture, reca...  entertainment

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                             original
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...

# %%
def prep_article_data(df, column, extra_words=[], exclude_words=[]):
    '''
    This function take in a df and the string name for a text column with 
    option to pass lists for extra_words and exclude_words and
    returns a df with the text article title, original text, stemmed text,
    lemmatized text, cleaned, tokenized, & lemmatized text with stopwords removed.
    '''
    df['clean'] = df[column].apply(basic_clean)\
                            .apply(tokenize)\
                            .apply(remove_stopwords,
                                  extra_words=extra_words,
                                  exclude_words=exclude_words)
    
    df['stemmed'] = df['clean'].apply(stem)
    
    df['lemmatized'] = df['clean'].apply(lemmatize)
    
    return df[['title', column,'clean', 'stemmed', 'lemmatized']]

# %%
prep_article_data(news_df, 'original', extra_words = ['ha'], exclude_words = ['no'])
# Out:
#                                                 title  \
# 0   Antfin transfers 10.3% stake to Paytm chief Vi...
# 1   Nepal asks India for rice, sugar to avert poss...
# 2   GQG Partners buys 8.1% stake in Adani Power fo...
# 3   USDA cuts rice trade forecast for 2023, 2024 p...
# 4   Hyundai to buy General Motors' Talegaon plant ...
# 5   Nifty50 firms chiefs' average remuneration dro...
# 6   H&M probes labour abuses at Myanmar garment fa...
# 7   Irish bank glitch lets people with no money wi...
# 8   Union Cabinet approves ₹32,500 crore for seven...
# 9            Netherlands slips into recession
# 10  India's Gukesh D, Vidit Gujrathi crash out of ...
# 11  After scoring 369 runs in 2 matches, Shaw rule...
# 12  I do not make the pitch, I do not roll the pit...
# 13  Kishan flaunts his new MS Dhoni-like look with...
# 14  Imran is our greatest player: Ex-Pak captain M...
# 15  Was smashed for sixes, had to learn a lot: Ash...
# 16  Kohli demanded excellence, current team lacks ...
# 17  Dhawan doesn't get credit, he was missed in 20...
# 18  I guess he will get his British passport soon,...
# 19  Ravichandran Ashwin clarifies his 'Now everybo...
# 20  I've been locked out of X for 17 days after re...
# 21  Scientists reconstruct Pink Floyd song from re...
# 22  Russia's Luna-25 spacecraft enters lunar orbit...
# 23  Aditya-L1 to study the Sun's atmosphere, space...
# 24  Cabinet extends Digital India program with ₹14...
# 25  TweetDeck now called XPro, goes behind paywall...
# 26  Heartening: MoS Science on Chandrayaan-3 finis...
# 27  Why is Apple paying $500 million to select iPh...
# 28  Tech has progressed faster in India compared t...
# 29  17 & 18-year-olds accused of hacking Nvidia, b...
# 30  Aditya & Karan couldn't make better films than...
# 31  I am seriously considering making Mahabharat: ...
# 32  Govt refutes report of Gadar 2 'VIP screening'...
# 33  Salman Khan once called me a fat cow, said 'ev...
# 34  Was offered Sidharth Shukla's season of Bigg B...
# 35  Ranbir Kapoor buys Range Rover car worth ₹4 cr...
# 36  SRK reacts to Gauri's post on Suhana, says she...
# 37  Can be my authentic self with him: Alia on Ran...
# 38  Alia talks about 'toxicity' amid criticism aga...
# 39  Was 18, it was my homecoming as Miss Universe:...
#
#                                              original  \
# 0   Antfin (Netherlands) Holding BV has transferre...
# 1   Nepal government has requested India to facili...
# 2   Investment firm GQG Partners bought an 8.1% st...
# 3   US Department of Agriculture (USDA) lowered th...
# 4   Hyundai Motor India signed an asset purchase a...
# 5   Combined remuneration for the heads of the Nif...
# 6   H&M is investigating 20 alleged instances of l...
# 7   A glitch in Bank of Ireland's app allowed cust...
# 8   Union Cabinet approved a ₹32,500-crore budget ...
# 9   The Dutch economy has entered a recession as i...
# 10  India's Gukesh D and Vidit Gujrathi have crash...
# 11  Northamptonshire's Indian batter Prithvi Shaw ...
# 12  Talking about rank turners in India, all-round...
# 13  Team India wicketkeeper-batter Ishan Kishan to...
# 14  Talking about Pakistan's 1992 World Cup-winnin...
# 15  Talking about his first tour of Australia in 2...
# 16  Ex-India cricketer Balwinder Singh Sandhu, who...
# 17  Ex-Team India head coach Ravi Shastri said bat...
# 18  Talking about Cheteshwar Pujara's county crick...
# 19  Ravichandran Ashwin clarified his remark where...
# 20  Scott Galloway, a Professor of Marketing at NY...
# 21  Researchers from the University of California,...
# 22  Russia's lunar spacecraft entered the Moon's o...
# 23  The Indian Space Research Organisation (ISRO) ...
# 24  The Cabinet has extended Digital India program...
# 25  XPro, earlier called TweetDeck, has been put b...
# 26  After ISRO said it had successfully carried ou...
# 27  Apple will start paying $500 million ($65 each...
# 28  Intel's Executive Vice President and General M...
# 29  A 17 and an 18-year-old are accused of being "...
# 30  Actress Farida Jalal said she still feels that...
# 31  Filmmaker Vivek Agnihotri said he is "seriousl...
# 32  Government has refuted report of an "Exclusive...
# 33  Speaking with Siddharth Kannan, Rohit Roy reca...
# 34  Rapper Emiway Bantai shared he was offered 'Bi...
# 35  Actor Ranbir Kapoor has bought a new Range Rov...
# 36  Shah Rukh Khan, reacting to Gauri Khan's post ...
# 37  Actress Alia Bhatt, during an Ask Me Anything ...
# 38  Alia Bhatt talked about "toxicity and criticis...
# 39  Sushmita Sen, reacting to an old picture, reca...
#
#                                                 clean  \
# 0   antfin netherlands holding bv transferred 103 ...
# 1   nepal government requested india facilitate su...
# 2   investment firm gqg partners bought 81 stake a...
# 3   us department agriculture usda lowered global ...
# 4   hyundai motor india signed asset purchase agre...
# 5   combined remuneration heads nifty50 companies ...
# 6   hm investigating 20 alleged instances labour a...
# 7   glitch bank ireland ' app allowed customers lo...
# 8   union cabinet approved 32500crore budget seven...
# 9   dutch economy entered recession shrank 03 quar...
# 10  india ' gukesh vidit gujrathi crashed chess wo...
# 11  northamptonshire ' indian batter prithvi shaw ...
# 12  talking rank turners india allrounder ravichan...
# 13  team india wicketkeeperbatter ishan kishan too...
# 14  talking pakistan ' 1992 world cupwinning capta...
# 15  talking first tour australia 2011 india spinne...
# 16  exindia cricketer balwinder singh sandhu part ...
# 17  exteam india head coach ravi shastri said batt...
# 18  talking cheteshwar pujara ' county cricket one...
# 19  ravichandran ashwin clarified remark wherein s...
# 20  scott galloway professor marketing nyu stern s...
# 21  researchers university california berkeley use...
# 22  russia ' lunar spacecraft entered moon ' orbit...
# 23  indian space research organisation isro launch...
# 24  cabinet extended digital india program additio...
# 25  xpro earlier called tweetdeck put behind paywa...
# 26  isro said successfully carried final orbit red...
# 27  apple start paying 500 million 65 select iphon...
# 28  intel ' executive vice president general manag...
# 29  17 18yearold accused key players lapsus hacked...
# 30  actress farida jalal said still feels ' dilwal...
# 31  filmmaker vivek agnihotri said seriously consi...
# 32  government refuted report exclusive vip screen...
# 33  speaking siddharth kannan rohit roy recalled p...
# 34  rapper emiway bantai shared offered ' bigg bos...
# 35  actor ranbir kapoor bought new range rover car...
# 36  shah rukh khan reacting gauri khan ' post suha...
# 37  actress alia bhatt ask anything session instag...
# 38  alia bhatt talked toxicity criticism hours act...
# 39  sushmita sen reacting old picture recalled tak...
#
#                                               stemmed  \
# 0   antfin netherland hold bv transfer 103 stake o...
# 1   nepal govern request india facilit suppli padd...
# 2   invest firm gqg partner bought 81 stake adani ...
# 3   us depart agricultur usda lower global rice tr...
# 4   hyundai motor india sign asset purchas agreeme...
# 5   combin remuner head nifty50 compani fell 25 10...
# 6   hm investig 20 alleg instanc labour abus myanm...
# 7   glitch bank ireland ' app allow custom low bal...
# 8   union cabinet approv 32500crore budget seven r...
# 9   dutch economi enter recess shrank 03 quarterli...
# 10  india ' gukesh vidit gujrathi crash chess worl...
# 11  northamptonshir ' indian batter prithvi shaw r...
# 12  talk rank turner india allround ravichandran a...
# 13  team india wicketkeeperbatt ishan kishan took ...
# 14  talk pakistan ' 1992 world cupwin captain imra...
# 15  talk first tour australia 2011 india spinner r...
# 16  exindia cricket balwind singh sandhu part indi...
# 17  exteam india head coach ravi shastri said batt...
# 18  talk cheteshwar pujara ' counti cricket oneday...
# 19  ravichandran ashwin clarifi remark wherein sta...
# 20  scott galloway professor market nyu stern scho...
# 21  research univers california berkeley use brain...
# 22  russia ' lunar spacecraft enter moon ' orbit w...
# 23  indian space research organis isro launch firs...
# 24  cabinet extend digit india program addit outla...
# 25  xpro earlier call tweetdeck put behind paywal ...
# 26  isro said success carri final orbit reduct man...
# 27  appl start pay 500 million 65 select iphon use...
# 28  intel ' execut vice presid gener manag data ce...
# 29  17 18yearold accus key player lapsu hack serve...
# 30  actress farida jalal said still feel ' dilwal ...
# 31  filmmak vivek agnihotri said serious consid ma...
# 32  govern refut report exclus vip screen sunni de...
# 33  speak siddharth kannan rohit roy recal phase f...
# 34  rapper emiway bantai share offer ' bigg boss '...
# 35  actor ranbir kapoor bought new rang rover car ...
# 36  shah rukh khan react gauri khan ' post suhana ...
# 37  actress alia bhatt ask anyth session instagram...
# 38  alia bhatt talk toxic critic hour actorhusband...
# 39  sushmita sen react old pictur recal taken retu...
#
#                                            lemmatized
# 0   antfin netherlands holding bv transferred 103 ...
# 1   nepal government requested india facilitate su...
# 2   investment firm gqg partner bought 81 stake ad...
# 3   u department agriculture usda lowered global r...
# 4   hyundai motor india signed asset purchase agre...
# 5   combined remuneration head nifty50 company fel...
# 6   hm investigating 20 alleged instance labour ab...
# 7   glitch bank ireland ' app allowed customer low...
# 8   union cabinet approved 32500crore budget seven...
# 9   dutch economy entered recession shrank 03 quar...
# 10  india ' gukesh vidit gujrathi crashed chess wo...
# 11  northamptonshire ' indian batter prithvi shaw ...
# 12  talking rank turner india allrounder ravichand...
# 13  team india wicketkeeperbatter ishan kishan too...
# 14  talking pakistan ' 1992 world cupwinning capta...
# 15  talking first tour australia 2011 india spinne...
# 16  exindia cricketer balwinder singh sandhu part ...
# 17  exteam india head coach ravi shastri said batt...
# 18  talking cheteshwar pujara ' county cricket one...
# 19  ravichandran ashwin clarified remark wherein s...
# 20  scott galloway professor marketing nyu stern s...
# 21  researcher university california berkeley used...
# 22  russia ' lunar spacecraft entered moon ' orbit...
# 23  indian space research organisation isro launch...
# 24  cabinet extended digital india program additio...
# 25  xpro earlier called tweetdeck put behind paywa...
# 26  isro said successfully carried final orbit red...
# 27  apple start paying 500 million 65 select iphon...
# 28  intel ' executive vice president general manag...
# 29  17 18yearold accused key player lapsus hacked ...
# 30  actress farida jalal said still feel ' dilwale...
# 31  filmmaker vivek agnihotri said seriously consi...
# 32  government refuted report exclusive vip screen...
# 33  speaking siddharth kannan rohit roy recalled p...
# 34  rapper emiway bantai shared offered ' bigg bos...
# 35  actor ranbir kapoor bought new range rover car...
# 36  shah rukh khan reacting gauri khan ' post suha...
# 37  actress alia bhatt ask anything session instag...
# 38  alia bhatt talked toxicity criticism hour acto...
# 39  sushmita sen reacting old picture recalled tak...

# %%
prep_article_data(codeup_df, 'original', extra_words = ['ha'], exclude_words = ['no']).head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
#
#                                                clean  \
# 0  may traditionally known asian american pacific...
# 1  women tech panelist spotlight magdalena rahn c...
# 2  women tech panelist spotlight rachel robbinsma...
# 3  women tech panelist spotlight sarah mellor cod...
# 4  women tech panelist spotlight madeleine capper...
#
#                                              stemmed  \
# 0  may tradit known asian american pacif island a...
# 1  women tech panelist spotlight magdalena rahn c...
# 2  women tech panelist spotlight rachel robbinsma...
# 3  women tech panelist spotlight sarah mellor cod...
# 4  women tech panelist spotlight madelein capper ...
#
#                                           lemmatized
# 0  may traditionally known asian american pacific...
# 1  woman tech panelist spotlight magdalena rahn c...
# 2  woman tech panelist spotlight rachel robbinsma...
# 3  woman tech panelist spotlight sarah mellor cod...
# 4  woman tech panelist spotlight madeleine capper...

# %% [markdown]
# #### 9. Ask yourself:
#
# ##### If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
# - It would not matter stemmed or lemmatized text because it is very small corpus

# %% [markdown]
# ##### If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
# For a 25MB corpus, the choice between stemmed and lemmatized text depends on analysis needs. Stemming is faster but might result in non-words. Lemmatization provides accurate words but is slower. Corpus size affects computation. The email analogy highlights 25MB limits for sending. So, the decision should focus on task requirements and trade-offs between speed and linguistic accuracy.

# %% [markdown]
# ##### If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?
# When dealing with a massive 200TB corpus and being charged by megabyte for computational resources, the choice between stemmed and lemmatized text depends on trade-offs. The choice trade-off of being  charged based on computer use, the choice is between quick but sometimes inaccurate cleaning (stemming) or slower but accurate cleaning (lemmatization)Stemming is faster and efficient for resource usage but might sacrifice linguistic accuracy. Lemmatization provides accurate results but is slower and resource-intensive. Consider your analysis needs, accuracy requirements, computational resources, and costs when making the decision. A hybrid approach could also be considered.
